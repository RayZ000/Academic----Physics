# %% [markdown]
# # **Youtube Videos Transcription with OpenAI's Whisper**
#
# [![blog post shield](https://img.shields.io/static/v1?label=&message=Blog%20post&color=blue&style=for-the-badge&logo=openai&link=https://openai.com/blog/whisper)](https://openai.com/blog/whisper)
# [![notebook shield](https://img.shields.io/static/v1?label=&message=Notebook&color=blue&style=for-the-badge&logo=googlecolab&link=https://colab.research.google.com/github/ArthurFDLR/whisper-youtube/blob/main/whisper_youtube.ipynb)](https://colab.research.google.com/github/ArthurFDLR/whisper-youtube/blob/main/whisper_youtube.ipynb)
# [![repository shield](https://img.shields.io/static/v1?label=&message=Repository&color=blue&style=for-the-badge&logo=github&link=https://github.com/openai/whisper)](https://github.com/openai/whisper)
# [![paper shield](https://img.shields.io/static/v1?label=&message=Paper&color=blue&style=for-the-badge&link=https://cdn.openai.com/papers/whisper.pdf)](https://cdn.openai.com/papers/whisper.pdf)
# [![model card shield](https://img.shields.io/static/v1?label=&message=Model%20card&color=blue&style=for-the-badge&link=https://github.com/openai/whisper/blob/main/model-card.md)](https://github.com/openai/whisper/blob/main/model-card.md)
#
# Whisper is a general-purpose speech recognition model. It is trained on a large dataset of diverse audio and is also a multi-task model that can perform multilingual speech recognition as well as speech translation and language identification.
#
# This Notebook will guide you through the transcription of a Youtube video using Whisper. You'll be able to explore most inference parameters or use the Notebook as-is to store the transcript and video audio in your Google Drive.

# %%
#@markdown # **Check GPU type** 🕵️

#@markdown The type of GPU you get assigned in your Colab session defined the speed at which the video will be transcribed.
#@markdown The higher the number of floating point operations per second (FLOPS), the faster the transcription.
#@markdown But even the least powerful GPU available in Colab is able to run any Whisper model.
#@markdown Make sure you've selected `GPU` as hardware accelerator for the Notebook (Runtime &rarr; Change runtime type &rarr; Hardware accelerator).

#@markdown |  GPU   |  GPU RAM   | FP32 teraFLOPS |     Availability   |
#@markdown |:------:|:----------:|:--------------:|:------------------:|
#@markdown |  T4    |    16 GB   |       8.1      |         Free       |
#@markdown | P100   |    16 GB   |      10.6      |      Colab Pro     |
#@markdown | V100   |    16 GB   |      15.7      |  Colab Pro (Rare)  |

#@markdown ---
#@markdown **Factory reset your Notebook's runtime if you want to get assigned a new GPU.**

# !nvidia-smi -L

# !nvidia-smi
# Out:
# GPU 0: Tesla T4 (UUID: GPU-bfb20c44-c5f1-1378-70ee-13a31ef623a0)
# Sat Jan 25 02:49:40 2025
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   49C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
#@markdown # **Install libraries** 🏗️
#@markdown This cell will take a little while to download several libraries, including Whisper.

#@markdown ---

! pip install git+https://github.com/openai/whisper.git
! pip install yt-dlp

import sys
import warnings
import whisper
from pathlib import Path
import yt_dlp
import subprocess
import torch
import shutil
import numpy as np
from IPython.display import display, Markdown, YouTubeVideo

device = torch.device('cuda:0')
print('Using device:', device, file=sys.stderr)
# Out:
# Collecting git+https://github.com/openai/whisper.git
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-hqu8l3do
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-hqu8l3do
#   Resolved https://github.com/openai/whisper.git to commit 517a43ecd132a2089d85f4ebc044728a71d49f6e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.11/dist-packages (from openai-whisper==20240930) (10.5.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.11/dist-packages (from openai-whisper==20240930) (0.60.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from openai-whisper==20240930) (1.26.4)
# Collecting tiktoken (from openai-whisper==20240930)
#   Downloading tiktoken-0.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from openai-whisper==20240930) (2.5.1+cu121)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from openai-whisper==20240930) (4.67.1)
# Requirement already satisfied: triton>=2 in /usr/local/lib/python3.11/dist-packages (from openai-whisper==20240930) (3.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from triton>=2->openai-whisper==20240930) (3.17.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba->openai-whisper==20240930) (0.43.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken->openai-whisper==20240930) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.11/dist-packages (from tiktoken->openai-whisper==20240930) (2.32.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper==20240930) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper==20240930) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper==20240930) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper==20240930) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper==20240930) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper==20240930) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper==20240930) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper==20240930) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper==20240930) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper==20240930) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper==20240930) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper==20240930) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper==20240930) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper==20240930) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper==20240930) (12.1.105)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper==20240930) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->openai-whisper==20240930) (12.6.85)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->openai-whisper==20240930) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20240930) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20240930) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20240930) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20240930) (2024.12.14)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->openai-whisper==20240930) (3.0.2)
# Downloading tiktoken-0.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 12.5 MB/s eta 0:00:00
# Building wheels for collected packages: openai-whisper
#   Building wheel for openai-whisper (pyproject.toml) ... done
#   Created wheel for openai-whisper: filename=openai_whisper-20240930-py3-none-any.whl size=803669 sha256=1e99670bea4a727d5fca7a523b58e153f5f09b397b970c70967fcf30a8fcbfa4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-dbqmr4zz/wheels/1f/1d/98/9583695e6695a6ac0ad42d87511097dce5ba486647dbfecb0e
# Successfully built openai-whisper
# Installing collected packages: tiktoken, openai-whisper
# Successfully installed openai-whisper-20240930 tiktoken-0.8.0
# Collecting yt-dlp
#   Downloading yt_dlp-2025.1.15-py3-none-any.whl.metadata (172 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.2/172.2 kB 3.4 MB/s eta 0:00:00
# Downloading yt_dlp-2025.1.15-py3-none-any.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 44.9 MB/s eta 0:00:00
# Installing collected packages: yt-dlp
# Successfully installed yt-dlp-2025.1.15
# Using device: cuda:0

# %%
#@markdown # **Optional:** Save data in Google Drive 💾
#@markdown Enter a Google Drive path and run this cell if you want to store the results inside Google Drive.

# Uncomment to copy generated images to drive, faster than downloading directly from colab in my experience.
from google.colab import drive
drive_mount_path = Path("/") / "content" / "drive"
drive.mount(str(drive_mount_path))
drive_mount_path /= "My Drive"
#@markdown ---
drive_path = "Colab Notebooks/Whisper Youtube" #@param {type:"string"}
#@markdown ---
#@markdown **Run this cell again if you change your Google Drive path.**

drive_whisper_path = drive_mount_path / Path(drive_path.lstrip("/"))
drive_whisper_path.mkdir(parents=True, exist_ok=True)
# Out:
# Mounted at /content/drive

# %%
#@markdown # **Model selection** 🧠

#@markdown As of the first public release, there are 4 pre-trained options to play with:

#@markdown |  Size  | Parameters | English-only model | Multilingual model | Required VRAM | Relative speed |
#@markdown |:------:|:----------:|:------------------:|:------------------:|:-------------:|:--------------:|
#@markdown |  tiny  |    39 M    |     `tiny.en`      |       `tiny`       |     ~1 GB     |      ~32x      |
#@markdown |  base  |    74 M    |     `base.en`      |       `base`       |     ~1 GB     |      ~16x      |
#@markdown | small  |   244 M    |     `small.en`     |      `small`       |     ~2 GB     |      ~6x       |
#@markdown | medium |   769 M    |    `medium.en`     |      `medium`      |     ~5 GB     |      ~2x       |
#@markdown | large  |   1550 M   |        N/A         |      `large`       |    ~10 GB     |       1x       |

#@markdown ---
Model = 'small' #@param ['tiny.en', 'tiny', 'base.en', 'base', 'small.en', 'small', 'medium.en', 'medium', 'large']
#@markdown ---
#@markdown **Run this cell again if you change the model.**

whisper_model = whisper.load_model(Model)

if Model in whisper.available_models():
    display(Markdown(
        f"**{Model} model is selected.**"
    ))
else:
    display(Markdown(
        f"**{Model} model is no longer available.**<br /> Please select one of the following:<br /> - {'<br /> - '.join(whisper.available_models())}"
    ))
# Out:
# 100%|███████████████████████████████████████| 461M/461M [00:07<00:00, 66.2MiB/s]
# /usr/local/lib/python3.11/dist-packages/whisper/__init__.py:150: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(fp, map_location=device)
# **small model is selected.**

# %%
#@markdown # **Video selection** 📺

#@markdown Enter the URL of the Youtube video you want to transcribe, wether you want to save the audio file in your Google Drive, and run the cell.

Type = "Youtube video or playlist" #@param ['Youtube video or playlist', 'Google Drive']
#@markdown ---
#@markdown #### **Youtube video or playlist**
URL = "https://www.youtube.com/watch?v=z0G9U94qws8" #@param {type:"string"}
# store_audio = True #@param {type:"boolean"}
#@markdown ---
#@markdown #### **Google Drive video, audio (mp4, wav), or folder containing video and/or audio files**
video_path = "Colab Notebooks/transcription/my_video.mp4" #@param {type:"string"}
#@markdown ---
#@markdown **Run this cell again if you change the video.**

video_path_local_list = []

if Type == "Youtube video or playlist":

    ydl_opts = {
        'format': 'm4a/bestaudio/best',
        'outtmpl': '%(id)s.%(ext)s',
        # ℹ️ See help(yt_dlp.postprocessor) for a list of available Postprocessors and their arguments
        'postprocessors': [{  # Extract audio using ffmpeg
            'key': 'FFmpegExtractAudio',
            'preferredcodec': 'wav',
        }]
    }

    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        error_code = ydl.download([URL])
        list_video_info = [ydl.extract_info(URL, download=False)]

    for video_info in list_video_info:
        video_path_local_list.append(Path(f"{video_info['id']}.wav"))

elif Type == "Google Drive":
    # video_path_drive = drive_mount_path / Path(video_path.lstrip("/"))
    video_path = drive_mount_path / Path(video_path.lstrip("/"))
    if video_path.is_dir():
        for video_path_drive in video_path.glob("**/*"):
            if video_path_drive.is_file():
                display(Markdown(f"**{str(video_path_drive)} selected for transcription.**"))
            elif video_path_drive.is_dir():
                display(Markdown(f"**Subfolders not supported.**"))
            else:
                display(Markdown(f"**{str(video_path_drive)} does not exist, skipping.**"))
            video_path_local = Path(".").resolve() / (video_path_drive.name)
            shutil.copy(video_path_drive, video_path_local)
            video_path_local_list.append(video_path_local)
    elif video_path.is_file():
        video_path_local = Path(".").resolve() / (video_path.name)
        shutil.copy(video_path, video_path_local)
        video_path_local_list.append(video_path_local)
        display(Markdown(f"**{str(video_path)} selected for transcription.**"))
    else:
        display(Markdown(f"**{str(video_path)} does not exist.**"))

else:
    raise(TypeError("Please select supported input type."))

for video_path_local in video_path_local_list:
    if video_path_local.suffix == ".mp4":
        video_path_local = video_path_local.with_suffix(".wav")
        result  = subprocess.run(["ffmpeg", "-i", str(video_path_local.with_suffix(".mp4")), "-vn", "-acodec", "pcm_s16le", "-ar", "16000", "-ac", "1", str(video_path_local)])
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=z0G9U94qws8
# [youtube] z0G9U94qws8: Downloading webpage
# [youtube] z0G9U94qws8: Downloading tv player API JSON
# [youtube] z0G9U94qws8: Downloading ios player API JSON
# [youtube] z0G9U94qws8: Downloading player 37364e28
# [youtube] z0G9U94qws8: Downloading m3u8 information
# [info] z0G9U94qws8: Downloading 1 format(s): 140
# [download] Destination: z0G9U94qws8.m4a
# [download] 100% of   19.57MiB in 00:00:03 at 5.99MiB/s
# [FixupM4a] Correcting container of "z0G9U94qws8.m4a"
# [ExtractAudio] Destination: z0G9U94qws8.wav
# Deleting original file z0G9U94qws8.m4a (pass -k to keep)
# [youtube] Extracting URL: https://www.youtube.com/watch?v=z0G9U94qws8
# [youtube] z0G9U94qws8: Downloading webpage
# [youtube] z0G9U94qws8: Downloading tv player API JSON
# [youtube] z0G9U94qws8: Downloading ios player API JSON
# [youtube] z0G9U94qws8: Downloading m3u8 information

# %%
#@markdown # **Run the model** 🚀

#@markdown Run this cell to execute the transcription of the video. This can take a while and very based on the length of the video and the number of parameters of the model selected above.

#@markdown ## **Parameters** ⚙️

#@markdown ### **Behavior control**
#@markdown ---
language = "Chinese" #@param ['Auto detection', 'Afrikaans', 'Albanian', 'Amharic', 'Arabic', 'Armenian', 'Assamese', 'Azerbaijani', 'Bashkir', 'Basque', 'Belarusian', 'Bengali', 'Bosnian', 'Breton', 'Bulgarian', 'Burmese', 'Castilian', 'Catalan', 'Chinese', 'Croatian', 'Czech', 'Danish', 'Dutch', 'English', 'Estonian', 'Faroese', 'Finnish', 'Flemish', 'French', 'Galician', 'Georgian', 'German', 'Greek', 'Gujarati', 'Haitian', 'Haitian Creole', 'Hausa', 'Hawaiian', 'Hebrew', 'Hindi', 'Hungarian', 'Icelandic', 'Indonesian', 'Italian', 'Japanese', 'Javanese', 'Kannada', 'Kazakh', 'Khmer', 'Korean', 'Lao', 'Latin', 'Latvian', 'Letzeburgesch', 'Lingala', 'Lithuanian', 'Luxembourgish', 'Macedonian', 'Malagasy', 'Malay', 'Malayalam', 'Maltese', 'Maori', 'Marathi', 'Moldavian', 'Moldovan', 'Mongolian', 'Myanmar', 'Nepali', 'Norwegian', 'Nynorsk', 'Occitan', 'Panjabi', 'Pashto', 'Persian', 'Polish', 'Portuguese', 'Punjabi', 'Pushto', 'Romanian', 'Russian', 'Sanskrit', 'Serbian', 'Shona', 'Sindhi', 'Sinhala', 'Sinhalese', 'Slovak', 'Slovenian', 'Somali', 'Spanish', 'Sundanese', 'Swahili', 'Swedish', 'Tagalog', 'Tajik', 'Tamil', 'Tatar', 'Telugu', 'Thai', 'Tibetan', 'Turkish', 'Turkmen', 'Ukrainian', 'Urdu', 'Uzbek', 'Valencian', 'Vietnamese', 'Welsh', 'Yiddish', 'Yoruba']
#@markdown > Language spoken in the audio, use `Auto detection` to let Whisper detect the language.
#@markdown ---
verbose = 'Live transcription' #@param ['Live transcription', 'Progress bar', 'None']
#@markdown > Whether to print out the progress and debug messages.
#@markdown ---
output_format = 'txt' #@param ['txt', 'vtt', 'srt', 'tsv', 'json', 'all']
#@markdown > Type of file to generate to record the transcription.
#@markdown ---
task = 'transcribe' #@param ['transcribe', 'translate']
#@markdown > Whether to perform X->X speech recognition (`transcribe`) or X->English translation (`translate`).
#@markdown ---

#@markdown <br/>

#@markdown ### **Optional: Fine tunning**
#@markdown ---
temperature = 0.15 #@param {type:"slider", min:0, max:1, step:0.05}
#@markdown > Temperature to use for sampling.
#@markdown ---
temperature_increment_on_fallback = 0.2 #@param {type:"slider", min:0, max:1, step:0.05}
#@markdown > Temperature to increase when falling back when the decoding fails to meet either of the thresholds below.
#@markdown ---
best_of = 5 #@param {type:"integer"}
#@markdown > Number of candidates when sampling with non-zero temperature.
#@markdown ---
beam_size = 8 #@param {type:"integer"}
#@markdown > Number of beams in beam search, only applicable when temperature is zero.
#@markdown ---
patience = 1.0 #@param {type:"number"}
#@markdown > Optional patience value to use in beam decoding, as in [*Beam Decoding with Controlled Patience*](https://arxiv.org/abs/2204.05424), the default (1.0) is equivalent to conventional beam search.
#@markdown ---
length_penalty = -0.05 #@param {type:"slider", min:-0.05, max:1, step:0.05}
#@markdown > Optional token length penalty coefficient (alpha) as in [*Google's Neural Machine Translation System*](https://arxiv.org/abs/1609.08144), set to negative value to uses simple length normalization.
#@markdown ---
suppress_tokens = "-1" #@param {type:"string"}
#@markdown > Comma-separated list of token ids to suppress during sampling; '-1' will suppress most special characters except common punctuations.
#@markdown ---
initial_prompt = "" #@param {type:"string"}
#@markdown > Optional text to provide as a prompt for the first window.
#@markdown ---
condition_on_previous_text = True #@param {type:"boolean"}
#@markdown > if True, provide the previous output of the model as a prompt for the next window; disabling may make the text inconsistent across windows, but the model becomes less prone to getting stuck in a failure loop.
#@markdown ---
fp16 = True #@param {type:"boolean"}
#@markdown > whether to perform inference in fp16.
#@markdown ---
compression_ratio_threshold = 2.4 #@param {type:"number"}
#@markdown > If the gzip compression ratio is higher than this value, treat the decoding as failed.
#@markdown ---
logprob_threshold = -1.0 #@param {type:"number"}
#@markdown > If the average log probability is lower than this value, treat the decoding as failed.
#@markdown ---
no_speech_threshold = 0.6 #@param {type:"slider", min:-0.0, max:1, step:0.05}
#@markdown > If the probability of the <|nospeech|> token is higher than this value AND the decoding has failed due to `logprob_threshold`, consider the segment as silence.
#@markdown ---

verbose_lut = {
    'Live transcription': True,
    'Progress bar': False,
    'None': None
}

args = dict(
    language = (None if language == "Auto detection" else language),
    verbose = verbose_lut[verbose],
    task = task,
    temperature = temperature,
    temperature_increment_on_fallback = temperature_increment_on_fallback,
    best_of = best_of,
    beam_size = beam_size,
    patience=patience,
    length_penalty=(length_penalty if length_penalty>=0.0 else None),
    suppress_tokens=suppress_tokens,
    initial_prompt=(None if not initial_prompt else initial_prompt),
    condition_on_previous_text=condition_on_previous_text,
    fp16=fp16,
    compression_ratio_threshold=compression_ratio_threshold,
    logprob_threshold=logprob_threshold,
    no_speech_threshold=no_speech_threshold
)

temperature = args.pop("temperature")
temperature_increment_on_fallback = args.pop("temperature_increment_on_fallback")
if temperature_increment_on_fallback is not None:
    temperature = tuple(np.arange(temperature, 1.0 + 1e-6, temperature_increment_on_fallback))
else:
    temperature = [temperature]

if Model.endswith(".en") and args["language"] not in {"en", "English"}:
    warnings.warn(f"{Model} is an English-only model but receipted '{args['language']}'; using English instead.")
    args["language"] = "en"

for video_path_local in video_path_local_list:
    display(Markdown(f"### {video_path_local}"))

    video_transcription = whisper.transcribe(
        whisper_model,
        str(video_path_local),
        temperature=temperature,
        **args,
    )

    # Save output
    whisper.utils.get_writer(
        output_format=output_format,
        output_dir=video_path_local.parent
    )(
        video_transcription,
        str(video_path_local.stem),
        options=dict(
            highlight_words=False,
            max_line_count=None,
            max_line_width=None,
        )
    )

    def exportTranscriptFile(ext: str):
        local_path = video_path_local.parent / video_path_local.with_suffix(ext).name
        export_path = drive_whisper_path / video_path_local.with_suffix(ext).name
        shutil.copy(
            local_path,
            export_path
        )
        display(Markdown(f"**Transcript file created: {export_path}**"))

    if output_format=="all":
        for ext in ('.txt', '.vtt', '.srt', '.tsv', '.json'):
            exportTranscriptFile(ext)
    else:
        exportTranscriptFile("." + output_format)
# Out:
# ### z0G9U94qws8.wav
# [00:00.000 --> 00:04.000] 无休止的暴雨 黑暗暗的超低云
# [00:04.000 --> 00:06.000] 我们在这样的环境里行驶
# [00:06.000 --> 00:09.000] 感受冰岛的末日美学
# [00:09.000 --> 00:13.000] 就像把我看到的这个恶劣天际的冰岛
# [00:13.000 --> 00:16.000] 和环境之类的拍下来
# [00:16.000 --> 00:19.000] 所以我们现在就是在开车到各个地方
# [00:19.000 --> 00:21.000] 我想体验它不同的地貌
# [00:22.000 --> 00:25.000] 在外面狂风暴雨
# [00:25.000 --> 00:28.000] 然后另次自己穿的成功一个成功裤
# [00:28.000 --> 00:30.000] 就比较难受
# [00:30.000 --> 00:31.000] 已经出去很久了
# [00:31.000 --> 00:34.000] 我不知道它是不是风快跑了
# [00:36.000 --> 00:37.000] 哇
# [00:37.000 --> 00:38.000] 这一天我都不想看了
# [00:38.000 --> 00:39.000] 我看了一张照片
# [00:39.000 --> 00:40.000] 我看了一张照片
# [00:40.000 --> 00:41.000] 我看了一张照片
# [00:41.000 --> 00:42.000] 我看了一张照片
# [00:42.000 --> 00:43.000] 我看了一张照片
# [00:43.000 --> 00:44.000] 我看了一张照片
# [00:44.000 --> 00:45.000] 我看了一张照片
# [00:45.000 --> 00:46.000] 我看了一张照片
# [00:46.000 --> 00:47.000] 我看了一张照片
# [00:47.000 --> 00:48.000] 我看了一张照片
# [00:48.000 --> 00:49.000] 我看了一张照片
# [00:50.000 --> 00:51.000] 哇
# [00:51.000 --> 00:53.000] 这个就直接往前上去
# [00:53.000 --> 00:54.000] 不行不行不行
# [00:54.000 --> 00:55.000] 我看下
# [01:19.000 --> 01:23.000] 我感觉
# [01:23.000 --> 01:26.000] 大自然母亲在拥抱着我
# [01:26.000 --> 01:27.000] 我刚这么走
# [01:27.000 --> 01:29.000] 就感觉左边有人抱着我
# [01:29.000 --> 01:30.000] 我感觉左边有人抱着我
# [01:30.000 --> 01:31.000] 哈哈哈
# [01:37.000 --> 01:39.000] 我是不太敢出去
# [01:39.000 --> 01:41.000] 听到的天气太恶劣了
# [01:41.000 --> 01:44.000] 但是你这个身上都是干的吧
# [01:44.000 --> 01:46.000] 身上还干着的吧
# [01:46.000 --> 01:47.000] 谁让它干的
# [01:47.000 --> 01:53.000] 我现在正在擦它
# [01:53.000 --> 01:55.000] 不知道会不会坏呢
# [01:55.000 --> 01:56.000] 你瞎说啊
# [01:56.000 --> 01:57.000] 我要被大
# [01:57.000 --> 01:58.000] 大人还是赔不起啊
# [01:58.000 --> 02:00.000] 我要被哈斯伟人看见
# [02:00.000 --> 02:04.000] 就是刚才是整个机身都是这样的
# [02:04.000 --> 02:05.000] 然后呢
# [02:06.000 --> 02:07.000] 我就是觉得
# [02:07.000 --> 02:09.000] 每一幕都很想拍下来
# [02:09.000 --> 02:11.000] 我们现在在奔赴末日
# [02:14.000 --> 02:16.000] 云雾遮挡住了远方的山
# [02:16.000 --> 02:18.000] 雨水把路面染成深邃的颜色
# [02:18.000 --> 02:20.000] 这条路好像没有镜头
# [02:20.000 --> 02:22.000] 我们就这样开着开着
# [02:22.000 --> 02:24.000] 突然发现路边出现了一幢房子
# [02:24.000 --> 02:26.000] 前面还停了几辆车
# [02:27.000 --> 02:28.000] 又累又饿的我们
# [02:28.000 --> 02:30.000] 就好像换一求生的时候
# [02:30.000 --> 02:31.000] 终于遇到了不及站
# [02:31.000 --> 02:33.000] 房子里的人们吃饭聊天
# [02:33.000 --> 02:34.000] 欢声笑语
# [02:34.000 --> 02:37.000] 跟外面恶劣的天气形成鲜明对比
# [02:37.000 --> 02:39.000] 有一种恍惚的不真实感
# [02:46.000 --> 02:51.000] 这个没想到居然中途能遇到这么一个休息点
# [02:51.000 --> 02:53.000] 有餐厅有酒店
# [02:53.000 --> 02:55.000] 它就是全部是一体化的
# [02:55.000 --> 02:57.000] 在这种荒野之中
# [02:57.000 --> 02:58.000] 就很有
# [02:58.000 --> 02:59.000] 哇你看那个车
# [02:59.000 --> 03:00.000] 哇哩妈呀
# [03:00.000 --> 03:01.000] 这红色吗
# [03:01.000 --> 03:03.000] 这改成什么了
# [03:03.000 --> 03:05.000] 你看它这个车哪去不了
# [03:05.000 --> 03:06.000] 它这个车哪都能去
# [03:06.000 --> 03:07.000] 还是个不够的车
# [03:07.000 --> 03:08.000] 你看这车
# [03:08.000 --> 03:09.000] 这车在哪里
# [03:09.000 --> 03:10.000] 这车在哪里
# [03:10.000 --> 03:11.000] 这车在哪里
# [03:11.000 --> 03:12.000] 这车在哪里
# [03:12.000 --> 03:13.000] 这车在哪里
# [03:13.000 --> 03:14.000] 这车在哪里
# [03:14.000 --> 03:15.000] 车哪都能去
# [03:15.000 --> 03:16.000] 还是个冰岛
# [03:16.000 --> 03:18.000] 我发现冰岛的加油站
# [03:18.000 --> 03:19.000] 都是一个
# [03:19.000 --> 03:20.000] 只有一个
# [03:20.000 --> 03:21.000] 还不算是一个站
# [03:21.000 --> 03:23.000] 就是只有一个
# [03:23.000 --> 03:24.000] 这里的迷雾
# [03:24.000 --> 03:26.000] 好像也没有镜头一样
# [03:26.000 --> 03:28.000] 我们找到了一座神秘的瀑布
# [03:36.000 --> 03:37.000] 这就能听到瀑布的声音了
# [03:37.000 --> 03:38.000] 我们走吧
# [03:38.000 --> 03:40.000] 先吃晚上11点
# [03:44.000 --> 03:45.000] 什么也看不到
# [03:49.000 --> 03:50.000] 这在这
# [03:52.000 --> 03:53.000] 叫什么叫
# [03:58.000 --> 04:00.000] 我现在已经在瀑布了一天了
# [04:02.000 --> 04:04.000] 这个感觉极其的危险
# [04:04.000 --> 04:06.000] 这儿站出来就没命了
# [04:07.000 --> 04:08.000] 哇
# [04:08.000 --> 04:10.000] 我觉得现在有一种
# [04:10.000 --> 04:11.000] 寄进领的感觉
# [04:12.000 --> 04:13.000] 这个地方其实下面
# [04:13.000 --> 04:14.000] 特别深
# [04:14.000 --> 04:15.000] 然后特别冰险
# [04:15.000 --> 04:17.000] 而且现在风特别大
# [04:17.000 --> 04:19.000] 就是如果你们下面
# [04:19.000 --> 04:21.000] 站有的人或者是跨崩
# [04:21.000 --> 04:22.000] 非常有好处
# [04:22.000 --> 04:23.000] 就没命了
# [04:24.000 --> 04:25.000] 非常可惜
# [04:32.000 --> 04:33.000] 我们在迷雾中等待
# [04:33.000 --> 04:35.000] 直到它微微显现
# [04:36.000 --> 04:37.000] 那一刻
# [04:37.000 --> 04:38.000] 我仿佛进入到了
# [04:38.000 --> 04:40.000] 普若米修斯里的世界
# [04:42.000 --> 04:44.000] 看完瀑布
# [04:44.000 --> 04:45.000] 已经是晚上12点多
# [04:45.000 --> 04:46.000] 云屋外的晚霞
# [04:46.000 --> 04:48.000] 把世界染成了淡红色
# [04:48.000 --> 04:49.000] 这是我们究竟
# [04:49.000 --> 04:50.000] 找到一个录音场
# [04:50.000 --> 04:51.000] 歇下
# [04:56.000 --> 04:58.000] 大家早上好啊
# [04:58.000 --> 05:00.000] 我们又在车里醒来的
# [05:00.000 --> 05:01.000] 真是美好的一天的
# [05:02.000 --> 05:03.000] 现在外面
# [05:03.000 --> 05:04.000] 挂着贼大的风
# [05:05.000 --> 05:06.000] 然后又下着贼大的雨
# [05:08.000 --> 05:09.000] 现在又没下了
# [05:10.000 --> 05:12.000] 介绍一下我们的录音地
# [05:14.000 --> 05:16.000] 我的马上现在形象老差了
# [05:16.000 --> 05:18.000] 这边是完全自住的
# [05:18.000 --> 05:19.000] 他们这边
# [05:19.000 --> 05:22.000] 自己投钱1700冰岛克
# [05:23.000 --> 05:24.000] 然后投了毕之后
# [05:24.000 --> 05:26.000] 也可以无限制用这个厕所
# [05:26.000 --> 05:27.000] 还没有给钱
# [05:27.000 --> 05:28.000] 昨天我太困了
# [05:28.000 --> 05:30.000] 现在来投下钱
# [05:30.000 --> 05:32.000] 这就是厕所和投钱的地方
# [05:34.000 --> 05:35.000] 然后我们车
# [05:35.000 --> 05:36.000] 昨天是从这边进来的
# [05:36.000 --> 05:37.000] 外面其实就是
# [05:37.000 --> 05:38.000] 比较大的公路
# [05:38.000 --> 05:39.000] 但是你一走进来
# [05:39.000 --> 05:40.000] 就会觉得
# [05:41.000 --> 05:44.000] 非常的安静 僻静
# [05:45.000 --> 05:47.000] 冰岛的地理环境也很多遍
# [05:47.000 --> 05:49.000] 明明昨天看瀑布的地方附近
# [05:49.000 --> 05:51.000] 看起来比较荒雾
# [05:51.000 --> 05:53.000] 但只要开车不到一个小时
# [05:53.000 --> 05:55.000] 就能来到这片绿艺昂然的地方
# [05:55.000 --> 05:56.000] 居然还有森林
# [05:59.000 --> 06:00.000] 我现在又来到了
# [06:00.000 --> 06:02.000] 昨天晚上我们经过的这个
# [06:02.000 --> 06:03.000] 制高点
# [06:03.000 --> 06:04.000] 这边有一个
# [06:04.000 --> 06:05.000] 制高点
# [06:05.000 --> 06:07.000] 这边的公路特别漂亮
# [06:07.000 --> 06:09.000] 然后昨天是蓝调时间
# [06:09.000 --> 06:11.000] 现在比起下着大暴雨
# [06:11.000 --> 06:13.000] 加冠大风
# [06:13.000 --> 06:14.000] 上面是乌云
# [06:14.000 --> 06:17.000] 现在有点晴朗的感觉了
# [06:17.000 --> 06:18.000] 我再去拍一张
# [06:18.000 --> 06:19.000] 我们可以看一下
# [06:19.000 --> 06:20.000] 同样的地方
# [06:20.000 --> 06:21.000] 不同的天气 不同光线
# [06:21.000 --> 06:22.000] 它拍出来的照片的氛围
# [06:22.000 --> 06:23.000] 是完全不一样的
# [06:35.000 --> 06:37.000] 我们刚刚正在查
# [06:37.000 --> 06:38.000] 下一步要去什么地方
# [06:38.000 --> 06:40.000] 就是我们没有做行程的
# [06:40.000 --> 06:42.000] 唯一好处就是
# [06:42.000 --> 06:44.000] 你运气的好的时候
# [06:44.000 --> 06:45.000] 我们可以突然发现一个
# [06:45.000 --> 06:46.000] 很神秘的地方
# [06:46.000 --> 06:47.000] 又会想去
# [06:47.000 --> 06:49.000] 又小潘刚刚在地的地方点
# [06:49.000 --> 06:51.000] 然后发现一个叫海德拉的地方
# [06:51.000 --> 06:52.000] 有人传了一张图
# [06:52.000 --> 06:53.000] 是这样的
# [06:53.000 --> 06:54.000] 一个雪山
# [06:54.000 --> 06:55.000] 但现在虽然没有雪
# [06:55.000 --> 06:57.000] 但是这个山的形状很吸引我
# [06:57.000 --> 06:59.000] 然后我就把它放到了
# [06:59.000 --> 07:01.000] 谷歌搜索里面去搜了
# [07:01.000 --> 07:02.000] 反正就是搜到这个山的位置
# [07:02.000 --> 07:04.000] 我们现在准备开到这个山里面去
# [07:04.000 --> 07:06.000] 刚好搜到它那边路线是通的
# [07:06.000 --> 07:07.000] 在冰島开车有一个
# [07:07.000 --> 07:09.000] 可以查是路况的一个网站
# [07:09.000 --> 07:10.000] 然后刚好那边也是个月路
# [07:10.000 --> 07:12.000] 我们这个车应该也可以去
# [07:12.000 --> 07:13.000] 走吧
# [07:13.000 --> 07:14.000] 我们已经来这好几天了
# [07:14.000 --> 07:15.000] 就一直盘旋在这一块地方
# [07:15.000 --> 07:16.000] 就根本没有走
# [07:16.000 --> 07:17.000] 这个时候的我
# [07:17.000 --> 07:18.000] 还不知道自己选择了
# [07:18.000 --> 07:19.000] 一条错误的路
# [07:19.000 --> 07:21.000] 并且前方有怎样的危险
# [07:21.000 --> 07:22.000] 在等待我们
# [07:22.000 --> 07:23.000] 途中要走一段1号公路
# [07:23.000 --> 07:25.000] 再转进月路线
# [07:25.000 --> 07:27.000] 但是刚好经过了著名景点
# [07:27.000 --> 07:28.000] 塞里亚兰瀑布
# [07:28.000 --> 07:29.000] 我们就打算下去看看
# [07:33.000 --> 07:35.000] 塞里亚兰瀑布高达60米
# [07:35.000 --> 07:37.000] 上方的埃亚菲亚德拉濱盖溶水
# [07:37.000 --> 07:38.000] 汇聚成河流
# [07:38.000 --> 07:39.000] 从这里一清二下
# [07:39.000 --> 07:40.000] 天气好的时候
# [07:40.000 --> 07:42.000] 经常能看到彩虹
# [07:42.000 --> 07:43.000] 相信很多人都看过
# [07:43.000 --> 07:45.000] 在这里拍摄的风光大片
# [07:45.000 --> 07:46.000] 我也穿上冲锋衣
# [07:46.000 --> 07:47.000] 全副武装
# [07:47.000 --> 07:49.000] 打算招到瀑布后的山洞里
# [07:49.000 --> 07:50.000] 去看看
# [07:50.000 --> 07:51.000] 来吧来吧来吧
# [07:54.000 --> 07:56.000] 还没走到瀑布旁边
# [07:56.000 --> 07:57.000] 给个石头来吧
# [08:02.000 --> 08:03.000] 来吧来吧
# [08:18.000 --> 08:20.000] 不知道有没有人和我一样喜欢淋雨
# [08:21.000 --> 08:22.000] 这趟是真的体会到了
# [08:22.000 --> 08:24.000] 瀑布盛影的辛苦
# [08:24.000 --> 08:25.000] 真的很佩服那些镜头
# [08:25.000 --> 08:26.000] 一点水都不沾
# [08:26.000 --> 08:29.000] 把瀑布清晰拍出来的摄影师们
# [08:29.000 --> 08:31.000] 从塞里亚兰瀑布的西边
# [08:31.000 --> 08:33.000] 一拐就进山了
# [08:33.000 --> 08:34.000] 这里也有不少
# [08:34.000 --> 08:36.000] 显微人质的隐藏瀑布
# [08:36.000 --> 08:37.000] 好在为无人机
# [08:37.000 --> 08:39.000] 能带大家去一探究竟
# [08:50.000 --> 08:52.000] 前面有大哥要过河了
# [08:53.000 --> 08:55.000] 这个河感就有点深了
# [08:55.000 --> 08:56.000] 看他过去就知道
# [08:56.000 --> 08:57.000] 你看他轮胎的高度
# [08:57.000 --> 08:59.000] 我们拍的很紧张
# [09:02.000 --> 09:03.000] 我觉得小泥可以过
# [09:03.000 --> 09:04.000] 可以过
# [09:04.000 --> 09:05.000] 能过的
# [09:05.000 --> 09:06.000] 没有那么深
# [09:06.000 --> 09:07.000] 他还不是小泥
# [09:07.000 --> 09:08.000] 他不是小泥
# [09:08.000 --> 09:09.000] 他是什么
# [09:09.000 --> 09:11.000] 他是
# [09:11.000 --> 09:12.000] 这是大泥
# [09:12.000 --> 09:14.000] 这里面其实是一条死路
# [09:14.000 --> 09:16.000] 并不能通往东边的海德阿侯山
# [09:16.000 --> 09:19.000] 并且还有很多条河流需要穿越
# [09:19.000 --> 09:20.000] 不过当时我并不知道
# [09:20.000 --> 09:22.000] 只是觉得开车过河
# [09:22.000 --> 09:24.000] 好自己好好玩
# [09:25.000 --> 09:28.000] 我们又遇到了一条河
# [09:32.000 --> 09:34.000] 这个河我刚看有一个大哥过了
# [09:34.000 --> 09:35.000] 所以我判断一下
# [09:35.000 --> 09:36.000] 那个深度应该也能过
# [09:36.000 --> 09:38.000] 然后更重要的是
# [09:38.000 --> 09:40.000] 这边有超级多的鸟
# [09:41.000 --> 09:42.000] 不知道是什么鸟雷
# [09:48.000 --> 09:49.000] 开车涉水的时候
# [09:49.000 --> 09:50.000] 听说不能太急
# [09:50.000 --> 09:52.000] 只要慢慢来就好了
# [09:52.000 --> 09:54.000] 我关掉了esp
# [09:54.000 --> 09:55.000] 打开了泥地模式
# [09:55.000 --> 09:56.000] 一开始觉得很顺利
# [09:56.000 --> 09:58.000] 但是没想到最后快上岸的地方
# [09:58.000 --> 09:59.000] 有一个小凹陷
# [09:59.000 --> 10:00.000] 车速一下子变慢
# [10:00.000 --> 10:02.000] 着实是给我吓了一跳
# [10:05.000 --> 10:06.000] 随着越来越深入
# [10:06.000 --> 10:09.000] 周围的植被也看起来越来越荒
# [10:12.000 --> 10:14.000] 然后我们有了新的发现
# [10:18.000 --> 10:20.000] 山顶那块黑黑的
# [10:20.000 --> 10:21.000] 就是埃亚非亚德拉冰川
# [10:21.000 --> 10:23.000] 一共宽80平方公里
# [10:23.000 --> 10:26.000] 覆盖了这一片山脉的整个山顶
# [10:26.000 --> 10:28.000] 接下来让我们把无人机
# [10:28.000 --> 10:29.000] 飞到上面去看看吧
# [10:51.000 --> 10:53.000] 看见前面这条大河
# [10:53.000 --> 10:55.000] 我本来以为这次穿越就要放弃了
# [10:55.000 --> 10:57.000] 但是没想到突然来到两大哥
# [10:57.000 --> 10:59.000] 说让我跟着它就能过
# [10:59.000 --> 11:01.000] 就是他说我们可以跟着它
# [11:01.000 --> 11:02.000] 带了盖子
# [11:02.000 --> 11:03.000] 给你
# [11:03.000 --> 11:04.000] 带了盖子
# [11:04.000 --> 11:05.000] 带了盖子
# [11:05.000 --> 11:06.000] 带了盖子
# [11:06.000 --> 11:07.000] 带了盖子
# [11:07.000 --> 11:08.000] 带了盖子
# [11:08.000 --> 11:09.000] 带了盖子
# [11:09.000 --> 11:10.000] 带了盖子
# [11:10.000 --> 11:11.000] 带了盖子
# [11:11.000 --> 11:12.000] 带了盖子
# [11:12.000 --> 11:13.000] 带了盖子
# [11:13.000 --> 11:14.000] 带了盖子
# [11:14.000 --> 11:15.000] 带了盖子
# [11:15.000 --> 11:16.000] 带了盖子
# [11:16.000 --> 11:17.000] 带了盖子
# [11:17.000 --> 11:18.000] 带了盖子
# [11:18.000 --> 11:19.000] 带了盖子
# [11:19.000 --> 11:20.000] 带了盖子
# [11:20.000 --> 11:21.000] 带了盖子
# [11:21.000 --> 11:22.000] 给我们有个经验
# [11:22.000 --> 11:23.000] 然后就可以过了
# [11:45.000 --> 11:46.000] 跟着大老走
# [11:46.000 --> 11:47.000] 哇去
# [11:48.000 --> 11:49.000] 我本来以为他跟我们车差不多
# [11:49.000 --> 11:50.000] 比我们车大多
# [11:58.000 --> 11:59.000] 加油加油加油
# [11:59.000 --> 12:00.000] 加油加油加油
# [12:00.000 --> 12:01.000] 加油加油加油
# [12:01.000 --> 12:02.000] 加油加油
# [12:03.000 --> 12:04.000] 我好害怕
# [12:04.000 --> 12:05.000] 真的可以有真的可以有
# [12:05.000 --> 12:06.000] 好害怕好害怕
# [12:06.000 --> 12:07.000] 加油加油
# [12:07.000 --> 12:08.000] 这个好深啊
# [12:08.000 --> 12:09.000] 哇
# [12:11.000 --> 12:12.000] 我的天啊
# [12:15.000 --> 12:17.000] 谢谢你 so much
# [12:18.000 --> 12:19.000] when you go back
# [12:19.000 --> 12:20.000] you try to go the same way
# [12:20.000 --> 12:21.000] yeah thank you
# [12:22.000 --> 12:23.000] bye have a nice day
# [12:23.000 --> 12:24.000]  have a nice day
# [12:24.000 --> 12:25.000] bye
# [12:35.000 --> 12:36.000] 哇
# [12:36.000 --> 12:37.000] 太酷了吧
# [12:37.000 --> 12:39.000] 他们是他们刚过来是吧
# [12:39.000 --> 12:40.000] 他们刚过来
# [12:40.000 --> 12:41.000] 他看了点秒
# [12:41.000 --> 12:43.000] 然后你看他问我是不是要过这河
# [12:43.000 --> 12:44.000] 从那过来一个就没人
# [12:44.000 --> 12:46.000] 然后又连续过了好几条河
# [12:46.000 --> 12:47.000] 我都觉得上瘾了
# [12:47.000 --> 12:49.000] 但是直到最后一条
# [12:49.000 --> 12:50.000] 我被前面的大哥拦住了
# [12:51.000 --> 12:52.000] 他在等我们
# [12:52.000 --> 12:53.000] 他在等我们
# [12:53.000 --> 12:54.000] 嗨
# [12:54.000 --> 12:55.000] 嗨
# [13:03.000 --> 13:04.000] 大哥说前面这条河
# [13:04.000 --> 13:06.000] 对美改装过的宿舍来说太深了
# [13:06.000 --> 13:07.000] 我们可以走另一边
# [13:07.000 --> 13:08.000] 前面有一个瘾地
# [13:08.000 --> 13:09.000] 在那边可以休息
# [13:09.000 --> 13:11.000] 最后还得到了他的许可
# [13:11.000 --> 13:13.000] 拍他的车过河
# [13:13.000 --> 13:15.000] 他们这个车也太简单了
# [13:15.000 --> 13:17.000] 这个车也太强了
# [13:30.000 --> 13:31.000] 哇
# [13:31.000 --> 13:32.000] 这个深
# [13:32.000 --> 13:33.000] 哇
# [13:33.000 --> 13:34.000] 这真的深
# [13:37.000 --> 13:39.000] 他也是刚刚好
# [13:39.000 --> 13:40.000] 底盘
# [13:41.000 --> 13:43.000] 整个车在这个河上面
# [13:43.000 --> 13:44.000] 我这个要进去就直接
# [13:44.000 --> 13:46.000] 直接就完了
# [13:49.000 --> 13:50.000] 哇
# [13:52.000 --> 13:53.000] 哇
# [13:55.000 --> 13:56.000] 太强了
# [13:56.000 --> 13:58.000] 我们跟着大哥的指引
# [13:58.000 --> 13:59.000] 继续沿着山谷往前开
# [13:59.000 --> 14:01.000] 然后就真的发现了一处瘾地
# [14:01.000 --> 14:03.000] 刚好他还有空的房间
# [14:03.000 --> 14:04.000] 我们就来体验一下
# [14:04.000 --> 14:07.000] 冰岛的山小屋是怎么样的吧
# [14:07.000 --> 14:10.000] 今天晚上就住在这边的小屋里
# [14:10.000 --> 14:11.000] 这也是
# [14:11.000 --> 14:13.000] 这个是冰岛的山小屋
# [14:13.000 --> 14:15.000] 我们要住的是这个大的
# [14:15.000 --> 14:17.000] 原来这里是按床位算的
# [14:17.000 --> 14:18.000] 两个人住以外
# [14:18.000 --> 14:20.000] 要17000元冰岛客人
# [14:20.000 --> 14:22.000] 洗澡的热水是500块4分钟
# [14:22.000 --> 14:23.000] 我们运气特别好
# [14:23.000 --> 14:25.000] 一楼的房间完全没人
# [14:25.000 --> 14:26.000] 所以也算是包间了
# [14:26.000 --> 14:29.000] 我想玩今天晚上就住在这边了
# [14:29.000 --> 14:31.000] 体验一下
# [14:31.000 --> 14:32.000] 哇
# [14:32.000 --> 14:33.000] 太棒了
# [14:34.000 --> 14:35.000] 非常有感觉
# [14:36.000 --> 14:38.000] 然后这边是留言铺
# [14:41.000 --> 14:43.000] 洗澡的地方
# [14:43.000 --> 14:46.000] 我们首次冰岛旅行的体验就不一样
# [14:46.000 --> 14:48.000] 体验住以下山小屋
# [14:48.000 --> 14:50.000] 然后这边真的算是山里面
# [14:50.000 --> 14:51.000] 要越野
# [14:51.000 --> 14:52.000] 两个小时才进来
# [14:52.000 --> 14:53.000] 很深的这个地方
# [14:53.000 --> 14:54.000] 在冰川下面
# [14:54.000 --> 14:56.000] 然后这边的山小屋
# [14:56.000 --> 14:59.000] 它是有路易地下山小屋
# [14:59.000 --> 15:00.000] 然后住的山小屋
# [15:00.000 --> 15:01.000] 我们你们住两天
# [15:01.000 --> 15:03.000] 车上我还想修整一下
# [15:03.000 --> 15:05.000] 然后我发现进来之后
# [15:05.000 --> 15:07.000] 他们这边房子真的很漂亮
# [15:07.000 --> 15:09.000] 我很喜欢这种氛围
# [15:09.000 --> 15:12.000] 这些和我在日本山小屋中间
# [15:12.000 --> 15:14.000] 有一些异曲同工征要
# [15:14.000 --> 15:17.000] 然后现在我要来拍一些照片
# [15:17.000 --> 15:19.000] 还可以把山小屋拿得过来
# [15:19.000 --> 15:22.000] 然后接下来就请大家看我
# [15:22.000 --> 15:23.000] 用哈苏拍的照片
# [15:23.000 --> 15:25.000] 来为你们介绍这个山小屋
# [15:25.000 --> 15:26.000] 看这张票不行
# [15:26.000 --> 15:28.000] 还是我拍视频给大家介绍了
# [15:29.000 --> 15:30.000] 啊
# [15:30.000 --> 15:31.000] 那你拍
# [15:31.000 --> 15:32.000] 这边有暖气
# [15:32.000 --> 15:34.000] 这还有一个壁炉
# [15:35.000 --> 15:36.000] 这还有一个
# [15:39.000 --> 15:40.000] 呢
# [16:01.000 --> 16:01.600] 我
# [16:01.600 --> 16:02.600] 谢谢
# [16:02.600 --> 16:08.500] 走
# [16:08.680 --> 16:11.120] 你在拍我嗎
# [16:11.180 --> 16:12.420] 吃飯了
# [16:12.600 --> 16:23.240] 現在你們睡個鐘了
# [16:23.240 --> 16:24.560] 他們還是正常在聊天
# [16:25.260 --> 16:28.200] 有兔子通話
# [16:28.200 --> 16:29.440] 这边是什么
# [16:29.440 --> 16:32.040] 好像说是Pasta
# [16:32.040 --> 16:33.280] 这种时候
# [16:33.280 --> 16:34.360] 它能想起来
# [16:34.360 --> 16:35.680] 泡面有多么的美好
# [16:35.680 --> 16:37.880] 还有欧美国家的泡面都没有什么很
# [16:37.880 --> 16:39.880] 很出名的 是不是
# [16:39.880 --> 16:43.680] 这绝对是大多数人来冰岛举行所
# [16:43.680 --> 16:45.680] 不太会体验到的
# [16:45.680 --> 16:50.680] 你觉得是第一个在这个山下屋吃泡面的人
# [16:50.680 --> 16:52.200] 这也很有可能
# [16:52.200 --> 16:53.680] 这个应该也好
# [16:53.680 --> 16:55.680] 让我来尝尝冰岛泡面
# [16:55.680 --> 16:56.680] 尝一尝
# [16:59.200 --> 17:01.200] 这难吃 我觉得
# [17:01.200 --> 17:04.200] 这玩意就不能比
# [17:04.200 --> 17:05.200] 我跟大家说一下吧
# [17:05.200 --> 17:07.200] 论词很少说一个东西难吃
# [17:08.200 --> 17:10.200] 这什么破音音
# [17:10.200 --> 17:11.200] 还是咱们亚洲的时候
# [17:11.200 --> 17:13.200] 他们居然点了个蜡烛
# [17:13.200 --> 17:16.200] 我怀疑他们根本就是这个工作人员
# [17:16.200 --> 17:18.200] 那边坐了一桌冰岛人
# [17:18.200 --> 17:20.200] 他们是自己当地人过来玩的
# [17:20.200 --> 17:22.200] 他们走之前有个人过来跟我聊天
# [17:22.200 --> 17:25.200] 我先问他关于水位的问题
# [17:25.200 --> 17:27.200] 我们不是过来创造很多河吗
# [17:27.200 --> 17:29.200] 然后他说就是早上走
# [17:29.200 --> 17:31.200] 水位会比较安全
# [17:31.200 --> 17:34.200] 我现在很担心我们明天会被困在这里
# [17:34.200 --> 17:36.200] 所以小白查了天气
# [17:36.200 --> 17:39.200] 明天早上是气下中下雨
# [17:39.200 --> 17:41.200] 他说我们可能得早点走
# [17:41.200 --> 17:43.200] 六点钟走 不能被困在这里
# [17:43.200 --> 17:47.200] 然后他说他开的是一个路循
# [17:47.200 --> 17:48.200] 我就问他说
# [17:48.200 --> 17:49.200] 如果买个路循
# [17:49.200 --> 17:51.200] 在冰岛能不能走穿所有路
# [17:51.200 --> 17:53.200] 他说不行
# [17:53.200 --> 17:54.200] 必须得改装
# [17:54.200 --> 17:56.200] 而且冰岛现在还有很多路
# [17:56.200 --> 17:58.200] 都是封闭的
# [17:58.200 --> 17:59.200] 还没有开
# [17:59.200 --> 18:00.200] 可能因为季节还没有到
# [18:00.200 --> 18:02.200] 他说可能再过两个月
# [18:02.200 --> 18:04.200] 更暖和之后血化差不多
# [18:04.200 --> 18:06.200] 然后宁宁的路
# [18:06.200 --> 18:07.200] 变得没有那么宁宁
# [18:07.200 --> 18:09.200] 变干了之后可能才能走
# [18:09.200 --> 18:10.200] 对 然后我们刚才看地图
# [18:10.200 --> 18:13.200] 就是我们今天走的路属于是EZ的
# [18:13.200 --> 18:14.200] 绿色路线可以通行
# [18:14.200 --> 18:16.200] 红色路线比较难
# [18:16.200 --> 18:18.200] 这是我当时犯的一个严重错误
# [18:18.200 --> 18:21.200] 红色其实是根本不可能通行的意思
# [18:21.200 --> 18:23.200] 当我第二天满心欢喜
# [18:23.200 --> 18:25.200] 去挑战所谓的红色高难度路线
# [18:25.200 --> 18:27.200] 寻找火山石
# [18:31.200 --> 18:33.200] 线车
# [18:33.200 --> 18:34.200] 怎么办呢
# [18:37.200 --> 18:40.200] 你知道就是斜着斜度
# [18:41.200 --> 18:43.200] 这个石头是我搬的
# [18:43.200 --> 18:44.200] 没有不干
# [18:44.200 --> 18:45.200] 我还找的
# [18:45.200 --> 18:47.200] 我还找的
# [18:48.200 --> 18:51.200] 我其实有意感这个地方过不去
# [18:52.200 --> 18:55.200] 我们玩过头了
# [18:55.200 --> 18:57.200] 在这个之前其实也有片雪地
# [18:57.200 --> 18:59.200] 我们直接驻跑冲了过来
# [18:59.200 --> 19:01.200] 但这个实在是太难了
# [19:01.200 --> 19:03.200] 我原本觉得这个距离的线车
# [19:03.200 --> 19:04.200] 很容易弄出来
# [19:04.200 --> 19:06.200] 但是我没有铲子也没有脱困板
# [19:06.200 --> 19:08.200] 血处一半融化的状态
# [19:08.200 --> 19:10.200] 积血的深度也超过了我的预期
# [19:10.200 --> 19:12.200] 随着脑胎越线越深
# [19:12.200 --> 19:14.200] 最终整个车的底盘都卡在了雪面上
# [19:14.200 --> 19:16.200] 我还是妥协 交了救援
# [19:16.200 --> 19:19.200] Hello my car was stuck
# [19:20.200 --> 19:21.200] You stuck
# [19:21.200 --> 19:22.200] Yes
# [19:22.200 --> 19:25.200] 然而因为我们错误走进了无法通行的路线
# [19:25.200 --> 19:27.200] 所以不在保险的肥肤范围内
# [19:29.200 --> 19:32.200] 所以旅行真的永远充满了惊喜和意外
# [19:32.200 --> 19:35.200] 你永远都不知道下一刻会发生什么
# [19:35.200 --> 19:37.200] 就比如在山小屋醒来的早晨
# [19:37.200 --> 19:39.200] 并没有预料症的下雨
# [19:39.200 --> 19:41.200] 早晨好啊 醒来了
# [19:41.200 --> 19:43.200] 早晨的阳光
# [19:43.200 --> 19:46.200] 这个光和昨天晚上还是差不多的
# [19:46.200 --> 19:47.200] 太爽了
# [19:47.200 --> 19:49.200] 昨天终于洗了到洗了头
# [19:50.200 --> 19:53.200] 还说外面现在是晴天
# [19:53.200 --> 19:56.200] 还并不是说在下雨
# [19:56.200 --> 19:58.200] 所以打算出于飞机
# [20:06.200 --> 20:08.200] 这里就是这条路的尽头了
# [20:08.200 --> 20:10.200] 我本来以为只是一个影帝而已
# [20:10.200 --> 20:11.200] 但是没想到
# [20:11.200 --> 20:13.200] 用无人机的视角来看
# [20:13.200 --> 20:14.200] 有这么的壮观
# [20:47.200 --> 20:49.200] 还不算太美
# [21:02.200 --> 21:04.200] 又来一道彩虹
# [21:04.200 --> 21:06.200] 第六道彩虹了
# [21:06.200 --> 21:08.200] 我的天啊
# **Transcript file created: /content/drive/My Drive/Colab Notebooks/Whisper Youtube/z0G9U94qws8.txt**
